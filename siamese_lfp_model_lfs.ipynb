# %%
# general libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import os
from scipy.io import loadmat
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
import h5py
import importlib
import warnings
from datetime import datetime
import matplotlib.pyplot as plt
import umap.umap_ as umap
# from mpl_toolkits.mplot3d import Axes3D  # noqa
# from mpl_toolkits.mplot3d import Axes3D  # noqa

# local libraries
import utils

# %%
# reload in case of change
importlib.reload(utils)
from utils import get_data_directory
from utils import get_device
from utils import create_timestamped_logdir

# %%
# ----------- Config ------------
SEGMENT_LENGTH = 10000  # 1 second @ 1kHz was 125 with a single fc layer performed relatively well
BATCH_SIZE = 64
EMBEDDING_DIM = 32 # 32 was really good
# LEARNING_RATE = 2e-5 # 1e4 had good results
LEARNING_RATE = 1e-3 # 1e-4 had good results
EPOCHS = 500
LOG_DIR = "runs/siamese_lfp3"
RUN_SIMULATION_DATA = False 
RUN_REAL_DATA = not RUN_SIMULATION_DATA
SIMULATION_DATA_SEPARABLE = True

# %%
# ----------- Data Preparation ------------
def segment_data(data, segment_length, shuffle=True):
    num_segments = len(data) // segment_length
    segments = np.array(np.split(data[:num_segments * segment_length], num_segments))
    if shuffle:
        np.random.shuffle(segments)
    return segments


# def create_pairs(gpi_segments, stn_segments):
#     pairs = []
#     labels = []

#     # GPi-GPi (label 0)
#     for i in range(len(gpi_segments) - 1):
#         pairs.append((gpi_segments[i], gpi_segments[i+1]))
#         labels.append(0)

#     # STN-STN (label 0)
#     for i in range(len(stn_segments) - 1):
#         pairs.append((stn_segments[i], stn_segments[i+1]))
#         labels.append(0)

#     # GPi-STN (label 1)
#     for i in range(min(len(gpi_segments), len(stn_segments))):
#         pairs.append((gpi_segments[i], stn_segments[i]))
#         labels.append(1)

#     ratio_similar = labels.count(0) / len(labels)
#     print(f"Similarity label ratio: {ratio_similar:.2f} similar (label 0), {1 - ratio_similar:.2f} dissimilar (label 1)")

#     return pairs, labels

def create_pairs(gpi_segments, stn_segments , min_dataset_size = 1000, max_dataset_size =5000):
    # GPi-GPi (label 0)
    dist = 1
    gpi_gpi_pairs = [(gpi_segments[i], gpi_segments[i+dist]) for i in range(len(gpi_segments) - dist)]
    while len(gpi_gpi_pairs)< min_dataset_size:
        dist = dist + 1 
        gpi_gpi_pairs.extend([(gpi_segments[i], gpi_segments[i+dist]) for i in range(len(gpi_segments) - dist)])
        
    # gpi_gpi_pairs.extend([(gpi_segments[i], gpi_segments[i+3]) for i in range(len(gpi_segments) - 3)])
    # gpi_gpi_pairs.extend([(gpi_segments[i], gpi_segments[i+4]) for i in range(len(gpi_segments) - 4)])
    gpi_gpi_labels = [0] * len(gpi_gpi_pairs)

    # STN-STN (label 0)
    dist = 1
    stn_stn_pairs = [(stn_segments[i], stn_segments[i+dist]) for i in range(len(stn_segments) - 1)]
    while len(stn_stn_pairs)< min_dataset_size:
        dist = dist + 1 
        stn_stn_pairs.extend([(stn_segments[i], stn_segments[i+dist]) for i in range(len(stn_segments) - dist)])
    # stn_stn_pairs.extend([(stn_segments[i], stn_segments    [i+2]) for i in range(len(stn_segments) - 2)])
    # stn_stn_pairs.extend([(stn_segments[i], stn_segments[i+3]) for i in range(len(stn_segments) - 3)])
    # stn_stn_pairs.extend([(stn_segments[i], stn_segments[i+4]) for i in range(len(stn_segments) - 4)])
    stn_stn_labels = [0] * len(stn_stn_pairs)

    # GPi-STN (label 1)
    dist = 0
    gpi_stn_pairs = [(gpi_segments[i], stn_segments[i]) for i in range(min(len(gpi_segments), len(stn_segments)))]
    while len(gpi_stn_pairs)< min_dataset_size:
        dist = dist + 1 
        gpi_stn_pairs.extend([(gpi_segments[i], stn_segments[i+dist]) for i in range(min(len(gpi_segments), len(stn_segments)) - dist)])
    # gpi_stn_pairs.extend([(gpi_segments[i], stn_segments[i+1]) for i in range(min(len(gpi_segments), len(stn_segments))-1)])
    # gpi_stn_pairs.extend([(gpi_segments[i+1], stn_segments[i]) for i in range(min(len(gpi_segments), len(stn_segments))-1)])
    # gpi_stn_pairs.extend([(gpi_segments[i], stn_segments[i+2]) for i in range(min(len(gpi_segments), len(stn_segments))-2)])
    gpi_stn_labels = [1] * len(gpi_stn_pairs)

    # Combine similar pairs
    similar_pairs = gpi_gpi_pairs + stn_stn_pairs
    similar_labels = gpi_gpi_labels + stn_stn_labels
    similar_labels = [0] * len(similar_pairs)

    combined_similar = list(zip(similar_pairs, similar_labels))
    np.random.shuffle(combined_similar)
    similar_pairs, similar_labels = zip(*combined_similar)
    similar_pairs, similar_labels = list(similar_pairs), list(similar_labels)

    # Balance both classes
    min_len = min(len(similar_pairs), len(gpi_stn_pairs), max_dataset_size)
    balanced_pairs = similar_pairs[:min_len] + gpi_stn_pairs[:min_len]
    balanced_labels = similar_labels[:min_len] + gpi_stn_labels[:min_len]

    ratio_similar = balanced_labels.count(0) / len(balanced_labels)
    print(f"Balanced similarity label ratio: {ratio_similar:.2f} similar (label 0), {1 - ratio_similar:.2f} dissimilar (label 1)")

    return balanced_pairs, balanced_labels


class LFPDataset(Dataset):
    def __init__(self, pairs, labels):
        self.pairs = pairs
        self.labels = labels

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        x1, x2 = self.pairs[idx]
        x1 = torch.tensor(x1, dtype=torch.float32).unsqueeze(0)
        x2 = torch.tensor(x2, dtype=torch.float32).unsqueeze(0)
        label = torch.tensor(self.labels[idx], dtype=torch.float32)
        return x1, x2, label

# %%
# ----------- Model Definition ------------
class CNNEncoder(nn.Module):
    def __init__(self, embedding_dim):
        super(CNNEncoder, self).__init__()
        # self.layers = nn.ModuleList([
        #     nn.Dropout(0.3),
        #     nn.Conv1d(1, 4, kernel_size=16, stride=2, padding=8),
        #     nn.BatchNorm1d(4),
        #     nn.ReLU(),
        #     nn.Dropout(0.3),
        #     nn.Conv1d(4, 8, kernel_size=32, stride=2, padding=16),
        #     nn.BatchNorm1d(8),
        #     nn.ReLU(),
        #     nn.Dropout(0.3),
        #     nn.Conv1d(8, 16, kernel_size=64, stride=2, padding=32),
        #     nn.BatchNorm1d(16),
        #     nn.ReLU(),
        #     # nn.Dropout(0.1),
        #     nn.Conv1d(16, 32, kernel_size=128, stride=2, padding=64),
        #     nn.BatchNorm1d(32),
        #     nn.ReLU(),
        #     # nn.Dropout(0.1),
        #     nn.Conv1d(32, 64, kernel_size=256, stride=2, padding=128),
        #     nn.BatchNorm1d(64),
        #     nn.ReLU(),
        #     # nn.Dropout(0.1),
        #     nn.Conv1d(64, 64, kernel_size=512, stride=2, padding=256),
        #     nn.BatchNorm1d(64),
        #     nn.ReLU(),
        #     nn.Dropout(0.3),
        #     nn.AdaptiveAvgPool1d(1)
        # ])

        self.layers = nn.ModuleList([
            nn.Dropout(0.3),
            nn.Conv1d(1, 32, kernel_size=32, stride=8, padding=0),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Conv1d(32, 64, kernel_size=32, stride=2, padding=0),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.5),
            # nn.Conv1d(64, 64, kernel_size=16, stride=2, padding=0),
            # nn.BatchNorm1d(64),
            # nn.ReLU(),
            # nn.Dropout(0.5),
            # nn.Conv1d(64, 64, kernel_size=8, stride=2, padding=0),
            # nn.BatchNorm1d(64),
            # nn.ReLU(),
            # nn.Dropout(0.5),
            # nn.Conv1d(64, 64, kernel_size=4, stride=2, padding=0),
            # nn.BatchNorm1d(64),
            # nn.ReLU(),
            # nn.Dropout(0.5),
            nn.Conv1d(64, 64, kernel_size=4, stride=2, padding=0),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.AdaptiveAvgPool1d(1)
            # nn.AdaptiveMaxPool1d(1)
        ])
        self.fc = nn.Sequential(
            nn.Linear(64, embedding_dim),
            # nn.ReLU(),
            # nn.Dropout(0.3),
            # nn.Linear(embedding_dim, embedding_dim//2),
            # nn.ReLU(),
            # nn.Dropout(0.3),
            # nn.Linear(embedding_dim//2,embedding_dim//4)  # Final layer maps to embedding space
        )
        # self.fc = nn.Linear(64, embedding_dim) # achived 58.8 percent testing accuracy

    def forward(self, x):
        for i, layer in enumerate(self.layers):
            x = layer(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
    def embed(self, x):
        for i, layer in enumerate(self.layers):
            x = layer(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Total trainable parameters: {total:,}\n")
    print("Trainable parameters by layer:")
    for name, param in model.named_parameters():
        if param.requires_grad:
            print(f"{name:50} {param.numel():,}")


def print_model_summary(model, train_loader, device):
    print("===== Sample Forward Pass Shape Info =====")
    x_sample = next(iter(train_loader))[0].to(device)
    model.encoder(x_sample)
    print("\nModel Summary:\n")
    print(model)
    count_parameters(model)


class SiameseNet(nn.Module):
    def __init__(self, embedding_dim):
        super(SiameseNet, self).__init__()
        self.encoder = CNNEncoder(embedding_dim)

    def forward(self, x1, x2):
        embed1 = self.encoder(x1)
        embed2 = self.encoder(x2)
        distance = F.pairwise_distance(embed1, embed2)
        # distance = 1 - F.cosine_similarity(embed1, embed2)
        return distance

# %%
# ----------- Training Loop ------------
def train(model, dataloader, optimizer, criterion, device, writer, epoch, print_tensors=False):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (x1, x2, label) in enumerate(dataloader):
        x1, x2, label = x1.to(device), x2.to(device), label.to(device)
        optimizer.zero_grad()
        output = model(x1, x2)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        preds = (output > 0.5).float()
        correct += (preds == label).sum()
        total += label.size(0)
        if i == 0 and print_tensors:
            print("Train Preds:", preds[:10])
            print("Train Labels:", label[:10])
        writer.add_scalar('Train/Batch_Loss', loss.item(), epoch * len(dataloader) + i)
    avg_loss = running_loss / len(dataloader)
    accuracy = correct / total
    print(f"Epoch {epoch+1} Train Accuracy: {accuracy:.4f}")
    writer.add_scalar('Train/Epoch_Loss', avg_loss, epoch)
    writer.add_scalar('Train/Accuracy', accuracy, epoch)
    return avg_loss


def evaluate(model, dataloader, criterion, device, writer, epoch, print_tensors=False):
    model.eval() # disable drop outs and does batch normalization in validation mode
    total_loss = 0.0
    correct = 0
    total = 0
    tcounter = 0
    with torch.no_grad():
        for x1, x2, label in dataloader:
            tcounter = tcounter + 1
            x1, x2, label = x1.to(device), x2.to(device), label.to(device)
            output = model(x1, x2)
            loss = criterion(output, label)
            total_loss += loss.item()
            preds = (output > 0.5).float()  # Same for both train and test
            correct += (preds == label).sum().item()
            total += label.size(0)
            if tcounter == 1 and print_tensors:
                print("Test Preds:", preds[0:15])
                print("Test Labels:", label[0:15])
    
    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    print(f"Epoch {epoch+1} Test Accuracy: {accuracy:.4f}")
    writer.add_scalar('Test/Epoch_Loss', avg_loss, epoch)
    writer.add_scalar('Test/Accuracy', accuracy, epoch)
    return avg_loss

def training_validate_loop(model, train_loader, test_loader, device, run_dir, epochs):
     
    # TensorBoard setup
    os.makedirs(run_dir, exist_ok=True)
    writer = SummaryWriter(run_dir)

    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
    # optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    # optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)

    criterion = contrastive_loss
    # criterion = nn.BCEWithLogitsLoss()


    model_save_path = run_dir + "\\full_siamese_model_best.pt"
    best_val_loss = float('inf')
    epochs_no_improve = 0
    patience = 100

    for epoch in range(epochs):
        train_loss = train(model, train_loader, optimizer, criterion, device, writer, epoch)
        validate_loss = evaluate(model, test_loader, criterion, device, writer, epoch)
        scheduler.step(validate_loss)
        current_lr = optimizer.param_groups[0]['lr']
        print(f"Epoch {epoch+1}/{epochs} - LR: {current_lr:.10f} - Train Loss: {train_loss:.4f} - Test Loss: {validate_loss:.4f}")
        writer.add_scalar('LearningRate', current_lr, epoch)

        # --- Early Stopping & Checkpoint ---
        if validate_loss < best_val_loss:
            best_val_loss = validate_loss
            # good idea to do this
            # checkpoint = {
            # 'model_state_dict': model.state_dict(),
            # 'optimizer_state_dict': optimizer.state_dict(),
            # 'epoch': epoch,
            # 'val_accuracy': val_acc,
            # 'train_loss': train_loss,
            # 'hyperparams': {
            #     'learning_rate': LEARNING_RATE,
            #     'dropout': 0.3,
            #     'weight_decay': 1e-4,
            #     'embedding_dim': EMBEDDING_DIM
            #     }
            # }
            torch.save(model, model_save_path)
            print(f" New best model saved at epoch {epoch+1}")
            epochs_no_improve = 0

        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f" Early stopping at epoch {epoch+1} (no improvement for {patience} epochs)")
                break
    
    writer.close()
    
    return torch.load(model_save_path, weights_only=False)



def contrastive_loss(distances, labels, margin=1.0):
        labels = labels.float()
        loss_similar = (1 - labels) * distances.pow(2)
        loss_dissimilar = labels * F.relu(margin - distances).pow(2)
        return torch.mean(loss_similar + loss_dissimilar)

# %% [markdown]
# # Visualization

# %%
# visualization 
def extract_embeddings(model, data_segments, label, device):
    model.eval()
    all_embeddings = []
    with torch.no_grad():
        for segment in data_segments:
            x = torch.tensor(segment, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)  # (1, 1, T)
            embedding = model.embed(x).cpu().numpy().squeeze()
            all_embeddings.append((embedding, label))
    return all_embeddings



def visualize_distance_heatmap(embeddings, metric='cosine'):
    dists = squareform(pdist(embeddings, metric=metric))
    plt.figure(figsize=(10, 8))
    sns.heatmap(dists, cmap='viridis')
    plt.title(f"Pairwise Distance Matrix ({metric})")
    plt.xlabel("Sample Index")
    plt.ylabel("Sample Index")
    plt.show()

def visualize(embeddings_with_labels, method='TSNE', TSNE_metric = 'euclidean'):
    embeddings = np.array([e for e, _ in embeddings_with_labels])
    labels = np.array([l for _, l in embeddings_with_labels])

    if method == 'TSNE': 
        tsne = TSNE(n_components=2, random_state=42, metric=TSNE_metric) # 'correlation' , 'cosine', 'manhattan' (L1 distance good for sparse),  'euclidean' (default)
        reduced = tsne.fit_transform(embeddings)
    elif  method == 'PCA': 
        pass 
    else:
        pass

    plt.figure(figsize=(8, 6))
    for label in np.unique(labels):
        idx = labels == label
        plt.scatter(reduced[idx, 0], reduced[idx, 1], label=f"{'GPi' if label < 2 else 'STN'}", alpha=0.7)

    plt.legend()
    plt.title("Functional Embedding Space")
    plt.xlabel("t-SNE Dim 1")
    plt.ylabel("t-SNE Dim 2")
    plt.grid(True)
    plt.show()

def visualize_embeddings(embeddings, labels, method="pca", metric="euclidean", mode="2d"):
    """
    Visualize high-dimensional embeddings using PCA, t-SNE, or UMAP.

    Args:
        embeddings (ndarray): Shape (n_samples, embedding_dim)
        labels (list or ndarray): Class labels for coloring
        method (str): 'pca', 'tsne', or 'umap'
        metric (str): Distance metric for t-SNE/UMAP ('euclidean', 'cosine', etc.)
        mode (str): '2d' or '3d'
    """
    labels = np.array(labels)
    method = method.lower()
    mode = mode.lower()
    assert method in {"pca", "tsne", "umap"}, "Method must be 'pca', 'tsne', or 'umap'"
    assert mode in {"2d", "3d"}, "Mode must be '2d' or '3d'"

    # Choose reducer
    if method == "pca":
        reducer = PCA(n_components=3 if mode == "3d" else 2)
    elif method == "tsne":
        reducer = TSNE(n_components=3 if mode == "3d" else 2, metric=metric, random_state=42)
    elif method == "umap":
        reducer = umap.UMAP(n_components=3 if mode == "3d" else 2, metric=metric, random_state=42,n_neighbors=500)

    reduced = reducer.fit_transform(embeddings)

    # Plotting
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection="3d") if mode == "3d" else plt.gca()

    for label in np.unique(labels):
        idx = labels == label
        coords = reduced[idx]
        if mode == "3d":
            ax.scatter(coords[:, 0], coords[:, 1], coords[:, 2], label=f"Label {label}", alpha=0.7)
        else:
            ax.scatter(coords[:, 0], coords[:, 1], label=f"Label {label}", alpha=0.7)

    ax.set_title(f"{method.upper()} Visualization ({metric})")
    ax.set_xlabel(f"{method.upper()} 1")
    ax.set_ylabel(f"{method.upper()} 2")
    if mode == "3d":
        ax.set_zlabel(f"{method.upper()} 3")
    ax.legend()
    plt.tight_layout()
    plt.grid(True)
    plt.show()

# %%
from scipy.signal import butter, filtfilt, resample

def lowpass_filter(signal, cutoff, fs, order=2):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    filtered = filtfilt(b, a, signal)
    return filtered

def filter_and_resample(signal, original_fs=24000, target_fs=1000, cutoff=500):
    # 1. Low-pass filter to prevent aliasing
    filtered = lowpass_filter(signal, cutoff=cutoff, fs=original_fs)

    # 2. Resample to target_fs
    duration_sec = len(signal) / original_fs
    target_num_samples = int(duration_sec * target_fs)
    resampled = resample(filtered, target_num_samples)

    return resampled

# %% [markdown]
# # Main pipeline (load and process data)

# %%
# def main():
    
# pipeline:
# get data (simulation or real)
# preprocessing normalize data
# process data for training
# train data (alot of parameters )
# visualzied points whether its on validatoin or training set or test set

# Get/generate data
if RUN_SIMULATION_DATA:
    # Generate synthetic LFP-like signals with sinusoids + noise
    if SIMULATION_DATA_SEPARABLE == False:
        fs = 24414
        duration_sec = 60 * 10
        t = np.linspace(0, duration_sec, fs * duration_sec, endpoint=False)
        gpi_signal = np.sin(2 * np.pi * 10 * t)*0.001  # 10 Hz sinusoid
        stn_signal = np.sin(2 * np.pi * 23 * t)*0.001  # 23 Hz sinusoid
        GPiData = gpi_signal + 0.0005 * np.random.randn(len(t))
        STNData = stn_signal + 0.0005 * np.random.randn(len(t))

    # Simulate random LFP-like signals which are not separable 
    else :
        GPiData = np.random.randn(24000 * 60 * 5)*0.001  # 2 minutes of data
        STNData = np.random.randn(24000 * 60 * 5)*0.001
    
else: 
    # load real data
    # for Sina's PC: F:\Python Projects\data\period9
    # for shared PC: D:\Sina\Data\period9\microSTN_L_3_CommonFiltered.mat
    print("1. Loading data ... ")
    dataPath = get_data_directory()
    with h5py.File(dataPath+ "lfs data\\microGPi1_L_4_CommonFiltered_lfs.mat", "r") as f:
        raw_gpi1 = np.array(f["data"]).squeeze()
        fs = int(np.array(f["fs"]).squeeze())
    with h5py.File(dataPath+ "lfs data\\microGPi1_L_5_CommonFiltered_lfs.mat", "r") as f:
        raw_gpi2 = np.array(f["data"]).squeeze()
    with h5py.File(dataPath+ "lfs data\\microGPi1_L_6_CommonFiltered_lfs.mat", "r") as f:
        raw_gpi3 = np.array(f["data"]).squeeze()
    with h5py.File(dataPath + "lfs data\\microVIM_L_4_CommonFiltered_lfs.mat", "r") as f:
        raw_stn1 = np.array(f["data"]).squeeze()  # replace with your actual filename
    with h5py.File(dataPath + "lfs data\\microVIM_L_5_CommonFiltered_lfs.mat", "r") as f:
        raw_stn2 = np.array(f["data"]).squeeze()  # replace with your actual filename
    with h5py.File(dataPath + "lfs data\\microVIM_L_6_CommonFiltered_lfs.mat", "r") as f:
        raw_stn3 = np.array(f["data"]).squeeze()  # replace with your actual filename
    

    # normalization 
    # GPiData = (raw_gpi - np.mean(raw_gpi)) / np.std(raw_gpi)
    # STNData = (raw_stn - np.mean(raw_stn)) / np.std(raw_stn)
    # print("2. preprocessing data (filtering and resampling) ...")
    # resampled_gpi1 = filter_and_resample(raw_gpi1, original_fs=fs, target_fs=1000, cutoff=500)
    # print("2. preprocessing data (filtering and resampling) ...")
    # resampled_gpi2 = filter_and_resample(raw_gpi2, original_fs=fs, target_fs=1000, cutoff=500)
    # print("2. preprocessing data (filtering and resampling) ...")
    # resampled_gpi3 = filter_and_resample(raw_gpi3, original_fs=fs, target_fs=1000, cutoff=500)
    # print("2. preprocessing data (filtering and resampling) ...")
    # resampled_stn1 = filter_and_resample(raw_stn1, original_fs=fs, target_fs=1000, cutoff=500)
    # print("2. preprocessing data (filtering and resampling) ...")
    # resampled_stn2 = filter_and_resample(raw_stn2, original_fs=fs, target_fs=1000, cutoff=500)
    # print("2. preprocessing data (filtering and resampling) ...")
    # resampled_stn3 = filter_and_resample(raw_stn3, original_fs=fs, target_fs=1000, cutoff=500)
    # print("2. preprocessing data (filtering and resampling) ...")
    # GPiData1 = (resampled_gpi1 - np.mean(resampled_gpi1)) / np.std(resampled_gpi1)
    # GPiData2 = (resampled_gpi2 - np.mean(resampled_gpi2)) / np.std(resampled_gpi2)
    # GPiData3 = (resampled_gpi3 - np.mean(resampled_gpi3)) / np.std(resampled_gpi3)
    # STNData1 = (resampled_stn1 - np.mean(resampled_stn1)) / np.std(resampled_stn1)
    # STNData2 = (resampled_stn2 - np.mean(resampled_stn2)) / np.std(resampled_stn2)
    # STNData3 = (resampled_stn3 - np.mean(resampled_stn3)) / np.std(resampled_stn3)


    print("2. preprocessing data (filtering and resampling) ...")
    GPiData1 = (raw_gpi1 - np.mean(raw_gpi1)) / np.std(raw_gpi1)
    GPiData2 = (raw_gpi2 - np.mean(raw_gpi2)) / np.std(raw_gpi2)
    GPiData3 = (raw_gpi3 - np.mean(raw_gpi3)) / np.std(raw_gpi3)
    STNData1 = (raw_stn1 - np.mean(raw_stn1)) / np.std(raw_stn1)
    STNData2 = (raw_stn2 - np.mean(raw_stn2)) / np.std(raw_stn2)
    STNData3 = (raw_stn3 - np.mean(raw_stn3)) / np.std(raw_stn3)
# Out:
# 1. Loading data ...
# 2. preprocessing data (filtering and resampling) ...

# %% [markdown]
# # Main pipeline (train and validate data)

# %%
# Print dataset shape and sizes
print("===== Dataset Information =====")

# Segment
# gpi_segments = segment_data(GPiData, SEGMENT_LENGTH)
# stn_segments = segment_data(STNData, SEGMENT_LENGTH)
gpi_segments1 = segment_data(GPiData1, SEGMENT_LENGTH)
gpi_segments2 = segment_data(GPiData2, SEGMENT_LENGTH)
gpi_segments3 = segment_data(GPiData3, SEGMENT_LENGTH)
gpi_segments = np.concatenate([gpi_segments1, gpi_segments2, gpi_segments3])
np.random.shuffle(gpi_segments)

stn_segments1 = segment_data(STNData1, SEGMENT_LENGTH)
stn_segments2 = segment_data(STNData2, SEGMENT_LENGTH)
stn_segments3 = segment_data(STNData3, SEGMENT_LENGTH)
stn_segments = np.concatenate([stn_segments1, stn_segments2, stn_segments3])
np.random.shuffle(stn_segments)

min_dataset_size = 20000
max_dataset_size = 20000
pairs, labels = create_pairs(gpi_segments, stn_segments, min_dataset_size, max_dataset_size)

# Split data
train_pairs, test_pairs, train_labels, test_labels = train_test_split( pairs, labels, test_size=0.2, stratify=labels, shuffle=True, random_state=42)

# Dataloaders
train_ds = LFPDataset(train_pairs, train_labels)
test_ds = LFPDataset(test_pairs, test_labels)
print(f"Train set: {len(train_ds)} pairs")
print(f"Test set: {len(test_ds)} pairs")
print(f"Batch size: {BATCH_SIZE}")
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)
print(f"Running on " + "Real data" if RUN_REAL_DATA else "Simulated data")
print("===== Training Input Shape Info =====")
for x1, x2, _ in train_loader:
    print(f"Train input shapes: x1: {x1.shape}, x2: {x2.shape}")
    break
print("===== Testing Input Shape Info =====")
for x1, x2, _ in test_loader:
    print(f"Test input shapes: x1: {x1.shape}, x2: {x2.shape}\n\n")
    break


# Check GPU
device = get_device()
print(f" Using {device}")

# Model setup
model = SiameseNet(embedding_dim=EMBEDDING_DIM).to(device)
print_model_summary(model, train_loader, device)

run_name = create_timestamped_logdir() + "_lfs_multi_channel" #add name if you want
trained_model = training_validate_loop(model, train_loader, test_loader, device, run_name, EPOCHS)
# Out:
# ===== Dataset Information =====
# Balanced similarity label ratio: 0.50 similar (label 0), 0.50 dissimilar (label 1)
# Train set: 32000 pairs
# Test set: 8000 pairs
# Batch size: 64
# Running on Real data
# ===== Training Input Shape Info =====
# Train input shapes: x1: torch.Size([64, 1, 10000]), x2: torch.Size([64, 1, 10000])
# ===== Testing Input Shape Info =====
# Test input shapes: x1: torch.Size([64, 1, 10000]), x2: torch.Size([64, 1, 10000])
#
#
#  Using cpu
# ===== Sample Forward Pass Shape Info =====
#
# Model Summary:
#
# SiameseNet(
#   (encoder): CNNEncoder(
#     (layers): ModuleList(
#       (0): Dropout(p=0.3, inplace=False)
#       (1): Conv1d(1, 32, kernel_size=(32,), stride=(8,))
#       (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#       (4): Dropout(p=0.5, inplace=False)
#       (5): Conv1d(32, 64, kernel_size=(32,), stride=(2,))
#       (6): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): Dropout(p=0.5, inplace=False)
#       (9): Conv1d(64, 64, kernel_size=(4,), stride=(2,))
#       (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Dropout(p=0.5, inplace=False)
#       (13): AdaptiveAvgPool1d(output_size=1)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=64, out_features=32, bias=True)
#     )
#   )
# )
# Total trainable parameters: 85,504
#
# Trainable parameters by layer:
# encoder.layers.1.weight                            1,024
# encoder.layers.1.bias                              32
# encoder.layers.2.weight                            32
# encoder.layers.2.bias                              32
# encoder.layers.5.weight                            65,536
# encoder.layers.5.bias                              64
# encoder.layers.6.weight                            64
# encoder.layers.6.bias                              64
# encoder.layers.9.weight                            16,384
# encoder.layers.9.bias                              64
# encoder.layers.10.weight                           64
# encoder.layers.10.bias                             64
# encoder.fc.0.weight                                2,048
# encoder.fc.0.bias                                  32
# f:\Python Projects\NIPS2025\utils.py:22: RuntimeWarning: ⚠️ CUDA is not available. The model will run on CPU, which may be slower.
#   warnings.warn("⚠️ CUDA is not available. The model will run on CPU, which may be slower.", RuntimeWarning)
# Epoch 1 Train Accuracy: 0.6459
# Epoch 1 Test Accuracy: 0.5863
# Epoch 1/500 - LR: 0.0010000000 - Train Loss: 0.2271 - Test Loss: 0.2547
#  New best model saved at epoch 1
# Epoch 2 Train Accuracy: 0.6858
# Epoch 2 Test Accuracy: 0.5739
# Epoch 2/500 - LR: 0.0010000000 - Train Loss: 0.2078 - Test Loss: 0.2604
# Epoch 3 Train Accuracy: 0.6878
# Epoch 3 Test Accuracy: 0.5978
# Epoch 3/500 - LR: 0.0010000000 - Train Loss: 0.2066 - Test Loss: 0.2450
#  New best model saved at epoch 3
# Epoch 4 Train Accuracy: 0.7021
# Epoch 4 Test Accuracy: 0.5991
# Epoch 4/500 - LR: 0.0010000000 - Train Loss: 0.1992 - Test Loss: 0.2465
# Epoch 5 Train Accuracy: 0.6993
# Epoch 5 Test Accuracy: 0.6211
# Epoch 5/500 - LR: 0.0010000000 - Train Loss: 0.1999 - Test Loss: 0.2355
#  New best model saved at epoch 5
# Epoch 6 Train Accuracy: 0.7077
# Epoch 6 Test Accuracy: 0.6268
# Epoch 6/500 - LR: 0.0010000000 - Train Loss: 0.1947 - Test Loss: 0.2325
#  New best model saved at epoch 6
# Epoch 7 Train Accuracy: 0.7055
# Epoch 7 Test Accuracy: 0.6019
# Epoch 7/500 - LR: 0.0010000000 - Train Loss: 0.1958 - Test Loss: 0.2459
# Epoch 8 Train Accuracy: 0.7137
# Epoch 8 Test Accuracy: 0.6014
# Epoch 8/500 - LR: 0.0010000000 - Train Loss: 0.1914 - Test Loss: 0.2501
# Epoch 9 Train Accuracy: 0.7173
# Epoch 9 Test Accuracy: 0.6040
# Epoch 9/500 - LR: 0.0010000000 - Train Loss: 0.1903 - Test Loss: 0.2468
# Epoch 10 Train Accuracy: 0.7223
# Epoch 10 Test Accuracy: 0.6019
# Epoch 10/500 - LR: 0.0010000000 - Train Loss: 0.1866 - Test Loss: 0.2487
# Epoch 11 Train Accuracy: 0.7285
# Epoch 11 Test Accuracy: 0.6475
# Epoch 11/500 - LR: 0.0010000000 - Train Loss: 0.1829 - Test Loss: 0.2189
#  New best model saved at epoch 11
# Epoch 12 Train Accuracy: 0.7446
# Epoch 12 Test Accuracy: 0.6684
# Epoch 12/500 - LR: 0.0010000000 - Train Loss: 0.1753 - Test Loss: 0.2134
#  New best model saved at epoch 12
# Epoch 13 Train Accuracy: 0.7674
# Epoch 13 Test Accuracy: 0.7079
# Epoch 13/500 - LR: 0.0010000000 - Train Loss: 0.1644 - Test Loss: 0.1979
#  New best model saved at epoch 13
# Epoch 14 Train Accuracy: 0.7818
# Epoch 14 Test Accuracy: 0.7020
# Epoch 14/500 - LR: 0.0010000000 - Train Loss: 0.1541 - Test Loss: 0.2228
# Epoch 15 Train Accuracy: 0.7968
# Epoch 15 Test Accuracy: 0.8184
# Epoch 15/500 - LR: 0.0010000000 - Train Loss: 0.1455 - Test Loss: 0.1393
#  New best model saved at epoch 15
# Epoch 16 Train Accuracy: 0.8125
# Epoch 16 Test Accuracy: 0.8167
# Epoch 16/500 - LR: 0.0010000000 - Train Loss: 0.1380 - Test Loss: 0.1407
# Epoch 17 Train Accuracy: 0.8202
# Epoch 17 Test Accuracy: 0.8283
# Epoch 17/500 - LR: 0.0010000000 - Train Loss: 0.1342 - Test Loss: 0.1375
#  New best model saved at epoch 17
# Epoch 18 Train Accuracy: 0.8312
# Epoch 18 Test Accuracy: 0.8251
# Epoch 18/500 - LR: 0.0010000000 - Train Loss: 0.1274 - Test Loss: 0.1626
# Epoch 19 Train Accuracy: 0.8364
# Epoch 19 Test Accuracy: 0.8179
# Epoch 19/500 - LR: 0.0010000000 - Train Loss: 0.1249 - Test Loss: 0.1406
# Epoch 20 Train Accuracy: 0.8433
# Epoch 20 Test Accuracy: 0.8361
# Epoch 20/500 - LR: 0.0010000000 - Train Loss: 0.1201 - Test Loss: 0.1416
# Epoch 21 Train Accuracy: 0.8440
# Epoch 21 Test Accuracy: 0.8512
# Epoch 21/500 - LR: 0.0010000000 - Train Loss: 0.1199 - Test Loss: 0.1310
#  New best model saved at epoch 21
# Epoch 22 Train Accuracy: 0.8491
# Epoch 22 Test Accuracy: 0.8452
# Epoch 22/500 - LR: 0.0010000000 - Train Loss: 0.1154 - Test Loss: 0.1392
# Epoch 23 Train Accuracy: 0.8518
# Epoch 23 Test Accuracy: 0.8334
# Epoch 23/500 - LR: 0.0010000000 - Train Loss: 0.1142 - Test Loss: 0.1616
# Epoch 24 Train Accuracy: 0.8536
# Epoch 24 Test Accuracy: 0.8450
# Epoch 24/500 - LR: 0.0010000000 - Train Loss: 0.1127 - Test Loss: 0.1386
# Epoch 25 Train Accuracy: 0.8556
# Epoch 25 Test Accuracy: 0.8367
# Epoch 25/500 - LR: 0.0010000000 - Train Loss: 0.1128 - Test Loss: 0.1579
# Epoch 26 Train Accuracy: 0.8614
# Epoch 26 Test Accuracy: 0.8639
# Epoch 26/500 - LR: 0.0010000000 - Train Loss: 0.1090 - Test Loss: 0.1258
#  New best model saved at epoch 26
# Epoch 27 Train Accuracy: 0.8671
# Epoch 27 Test Accuracy: 0.8151
# Epoch 27/500 - LR: 0.0010000000 - Train Loss: 0.1069 - Test Loss: 0.1679
# Epoch 28 Train Accuracy: 0.8677
# Epoch 28 Test Accuracy: 0.8393
# Epoch 28/500 - LR: 0.0010000000 - Train Loss: 0.1054 - Test Loss: 0.1603
# Epoch 29 Train Accuracy: 0.8647
# Epoch 29 Test Accuracy: 0.8532
# Epoch 29/500 - LR: 0.0010000000 - Train Loss: 0.1060 - Test Loss: 0.1388
# Epoch 30 Train Accuracy: 0.8653
# Epoch 30 Test Accuracy: 0.8545
# Epoch 30/500 - LR: 0.0010000000 - Train Loss: 0.1057 - Test Loss: 0.1360
# Epoch 31 Train Accuracy: 0.8709
# Epoch 31 Test Accuracy: 0.8396
# Epoch 31/500 - LR: 0.0010000000 - Train Loss: 0.1031 - Test Loss: 0.1714
# Epoch 32 Train Accuracy: 0.8691
# Epoch 32 Test Accuracy: 0.8569
# Epoch 32/500 - LR: 0.0005000000 - Train Loss: 0.1032 - Test Loss: 0.1530
# Epoch 33 Train Accuracy: 0.8734
# Epoch 33 Test Accuracy: 0.8401
# Epoch 33/500 - LR: 0.0005000000 - Train Loss: 0.1000 - Test Loss: 0.1788
# Epoch 34 Train Accuracy: 0.8761
# Epoch 34 Test Accuracy: 0.8595
# Epoch 34/500 - LR: 0.0005000000 - Train Loss: 0.0997 - Test Loss: 0.1448
# Epoch 35 Train Accuracy: 0.8825
# Epoch 35 Test Accuracy: 0.8374
# Epoch 35/500 - LR: 0.0005000000 - Train Loss: 0.0967 - Test Loss: 0.1604
# Epoch 36 Train Accuracy: 0.8810
# Epoch 36 Test Accuracy: 0.8374
# Epoch 36/500 - LR: 0.0005000000 - Train Loss: 0.0973 - Test Loss: 0.1772
# Epoch 37 Train Accuracy: 0.8832
# Epoch 37 Test Accuracy: 0.8401
# Epoch 37/500 - LR: 0.0005000000 - Train Loss: 0.0959 - Test Loss: 0.1833
# Epoch 38 Train Accuracy: 0.8855
# Epoch 38 Test Accuracy: 0.8455
# Epoch 38/500 - LR: 0.0002500000 - Train Loss: 0.0943 - Test Loss: 0.1632
# Epoch 39 Train Accuracy: 0.8849
# Epoch 39 Test Accuracy: 0.8466
# Epoch 39/500 - LR: 0.0002500000 - Train Loss: 0.0948 - Test Loss: 0.1624
# Epoch 40 Train Accuracy: 0.8901
# Epoch 40 Test Accuracy: 0.8419
# Epoch 40/500 - LR: 0.0002500000 - Train Loss: 0.0933 - Test Loss: 0.1747
# Epoch 41 Train Accuracy: 0.8907
# Epoch 41 Test Accuracy: 0.8450
# Epoch 41/500 - LR: 0.0002500000 - Train Loss: 0.0919 - Test Loss: 0.1707
# Epoch 42 Train Accuracy: 0.8848
# Epoch 42 Test Accuracy: 0.8530
# Epoch 42/500 - LR: 0.0002500000 - Train Loss: 0.0936 - Test Loss: 0.1512
# Epoch 43 Train Accuracy: 0.8862
# Epoch 43 Test Accuracy: 0.8434
# Epoch 43/500 - LR: 0.0002500000 - Train Loss: 0.0937 - Test Loss: 0.1677
# Epoch 44 Train Accuracy: 0.8902
# Epoch 44 Test Accuracy: 0.8411
# Epoch 44/500 - LR: 0.0001250000 - Train Loss: 0.0912 - Test Loss: 0.1705
# Epoch 45 Train Accuracy: 0.8914
# Epoch 45 Test Accuracy: 0.8515
# Epoch 45/500 - LR: 0.0001250000 - Train Loss: 0.0904 - Test Loss: 0.1630
# Epoch 46 Train Accuracy: 0.8918
# Epoch 46 Test Accuracy: 0.8420
# Epoch 46/500 - LR: 0.0001250000 - Train Loss: 0.0905 - Test Loss: 0.1780
# Epoch 47 Train Accuracy: 0.8914
# Epoch 47 Test Accuracy: 0.8356
# Epoch 47/500 - LR: 0.0001250000 - Train Loss: 0.0903 - Test Loss: 0.1912
# Epoch 48 Train Accuracy: 0.8910
# Epoch 48 Test Accuracy: 0.8440
# Epoch 48/500 - LR: 0.0001250000 - Train Loss: 0.0903 - Test Loss: 0.1697
# Epoch 49 Train Accuracy: 0.8879
# Epoch 49 Test Accuracy: 0.8137
# Epoch 49/500 - LR: 0.0001250000 - Train Loss: 0.0913 - Test Loss: 0.1993
# Epoch 50 Train Accuracy: 0.8934
# Epoch 50 Test Accuracy: 0.8347
# Epoch 50/500 - LR: 0.0000625000 - Train Loss: 0.0902 - Test Loss: 0.1779
# Epoch 51 Train Accuracy: 0.8922
# Epoch 51 Test Accuracy: 0.8396
# Epoch 51/500 - LR: 0.0000625000 - Train Loss: 0.0901 - Test Loss: 0.1775
# Epoch 52 Train Accuracy: 0.8927
# Epoch 52 Test Accuracy: 0.8371
# Epoch 52/500 - LR: 0.0000625000 - Train Loss: 0.0904 - Test Loss: 0.1781
# Epoch 53 Train Accuracy: 0.8945
# Epoch 53 Test Accuracy: 0.8492
# Epoch 53/500 - LR: 0.0000625000 - Train Loss: 0.0893 - Test Loss: 0.1642
# Epoch 54 Train Accuracy: 0.8953
# Epoch 54 Test Accuracy: 0.8317
# Epoch 54/500 - LR: 0.0000625000 - Train Loss: 0.0882 - Test Loss: 0.1831
# Epoch 55 Train Accuracy: 0.8944
# Epoch 55 Test Accuracy: 0.8314
# Epoch 55/500 - LR: 0.0000625000 - Train Loss: 0.0890 - Test Loss: 0.1799
# Epoch 56 Train Accuracy: 0.8952
# Epoch 56 Test Accuracy: 0.8391
# Epoch 56/500 - LR: 0.0000312500 - Train Loss: 0.0888 - Test Loss: 0.1772
# Epoch 57 Train Accuracy: 0.8966
# Epoch 57 Test Accuracy: 0.8414
# Epoch 57/500 - LR: 0.0000312500 - Train Loss: 0.0887 - Test Loss: 0.1715
# Epoch 58 Train Accuracy: 0.8958
# Epoch 58 Test Accuracy: 0.8315
# Epoch 58/500 - LR: 0.0000312500 - Train Loss: 0.0884 - Test Loss: 0.1848
# Epoch 59 Train Accuracy: 0.8949
# Epoch 59 Test Accuracy: 0.8366
# Epoch 59/500 - LR: 0.0000312500 - Train Loss: 0.0892 - Test Loss: 0.1802
# Epoch 60 Train Accuracy: 0.8940
# Epoch 60 Test Accuracy: 0.8201
# Epoch 60/500 - LR: 0.0000312500 - Train Loss: 0.0889 - Test Loss: 0.1973
# Epoch 61 Train Accuracy: 0.8915
# Epoch 61 Test Accuracy: 0.8450
# Epoch 61/500 - LR: 0.0000312500 - Train Loss: 0.0899 - Test Loss: 0.1700
# Epoch 62 Train Accuracy: 0.8953
# Epoch 62 Test Accuracy: 0.8329
# Epoch 62/500 - LR: 0.0000156250 - Train Loss: 0.0893 - Test Loss: 0.1805
# Epoch 63 Train Accuracy: 0.8964
# Epoch 63 Test Accuracy: 0.8317
# Epoch 63/500 - LR: 0.0000156250 - Train Loss: 0.0892 - Test Loss: 0.1851
# Epoch 64 Train Accuracy: 0.8951
# Epoch 64 Test Accuracy: 0.8438
# Epoch 64/500 - LR: 0.0000156250 - Train Loss: 0.0877 - Test Loss: 0.1663
# Epoch 65 Train Accuracy: 0.8951
# Epoch 65 Test Accuracy: 0.8274
# Epoch 65/500 - LR: 0.0000156250 - Train Loss: 0.0887 - Test Loss: 0.1902
# Epoch 66 Train Accuracy: 0.8956
# Epoch 66 Test Accuracy: 0.8251
# Epoch 66/500 - LR: 0.0000156250 - Train Loss: 0.0875 - Test Loss: 0.1893
# Epoch 67 Train Accuracy: 0.8937
# Epoch 67 Test Accuracy: 0.8488
# Epoch 67/500 - LR: 0.0000156250 - Train Loss: 0.0890 - Test Loss: 0.1670
# Epoch 68 Train Accuracy: 0.8965
# Epoch 68 Test Accuracy: 0.8321
# Epoch 68/500 - LR: 0.0000078125 - Train Loss: 0.0887 - Test Loss: 0.1830
# Epoch 69 Train Accuracy: 0.8937
# Epoch 69 Test Accuracy: 0.8454
# Epoch 69/500 - LR: 0.0000078125 - Train Loss: 0.0881 - Test Loss: 0.1712
# Epoch 70 Train Accuracy: 0.8935
# Epoch 70 Test Accuracy: 0.8420
# Epoch 70/500 - LR: 0.0000078125 - Train Loss: 0.0894 - Test Loss: 0.1776
# Epoch 71 Train Accuracy: 0.8928
# Epoch 71 Test Accuracy: 0.8433
# Epoch 71/500 - LR: 0.0000078125 - Train Loss: 0.0896 - Test Loss: 0.1774
# Epoch 72 Train Accuracy: 0.8941
# Epoch 72 Test Accuracy: 0.8327
# Epoch 72/500 - LR: 0.0000078125 - Train Loss: 0.0895 - Test Loss: 0.1852
# Epoch 73 Train Accuracy: 0.8950
# Epoch 73 Test Accuracy: 0.8433
# Epoch 73/500 - LR: 0.0000078125 - Train Loss: 0.0881 - Test Loss: 0.1699
# Epoch 74 Train Accuracy: 0.8936
# Epoch 74 Test Accuracy: 0.8313
# Epoch 74/500 - LR: 0.0000039063 - Train Loss: 0.0881 - Test Loss: 0.1835
# Epoch 75 Train Accuracy: 0.8954
# Epoch 75 Test Accuracy: 0.8357
# Epoch 75/500 - LR: 0.0000039063 - Train Loss: 0.0882 - Test Loss: 0.1815
# Epoch 76 Train Accuracy: 0.8997
# Epoch 76 Test Accuracy: 0.8261
# Epoch 76/500 - LR: 0.0000039063 - Train Loss: 0.0864 - Test Loss: 0.1940
# Epoch 77 Train Accuracy: 0.8944
# Epoch 77 Test Accuracy: 0.8376
# Epoch 77/500 - LR: 0.0000039063 - Train Loss: 0.0883 - Test Loss: 0.1775
# Epoch 78 Train Accuracy: 0.8967
# Epoch 78 Test Accuracy: 0.8466
# Epoch 78/500 - LR: 0.0000039063 - Train Loss: 0.0884 - Test Loss: 0.1690
# Epoch 79 Train Accuracy: 0.8955
# Epoch 79 Test Accuracy: 0.8369
# Epoch 79/500 - LR: 0.0000039063 - Train Loss: 0.0882 - Test Loss: 0.1743
# Epoch 80 Train Accuracy: 0.8983
# Epoch 80 Test Accuracy: 0.8269
# Epoch 80/500 - LR: 0.0000019531 - Train Loss: 0.0870 - Test Loss: 0.1893
# Epoch 81 Train Accuracy: 0.8970
# Epoch 81 Test Accuracy: 0.8213
# Epoch 81/500 - LR: 0.0000019531 - Train Loss: 0.0878 - Test Loss: 0.1943
# Epoch 82 Train Accuracy: 0.8988
# Epoch 82 Test Accuracy: 0.8304
# Epoch 82/500 - LR: 0.0000019531 - Train Loss: 0.0868 - Test Loss: 0.1867
# Epoch 83 Train Accuracy: 0.8958
# Epoch 83 Test Accuracy: 0.8424
# Epoch 83/500 - LR: 0.0000019531 - Train Loss: 0.0876 - Test Loss: 0.1768
# Epoch 84 Train Accuracy: 0.8952
# Epoch 84 Test Accuracy: 0.8397
# Epoch 84/500 - LR: 0.0000019531 - Train Loss: 0.0880 - Test Loss: 0.1729
# Epoch 85 Train Accuracy: 0.8964
# Epoch 85 Test Accuracy: 0.8385
# Epoch 85/500 - LR: 0.0000019531 - Train Loss: 0.0881 - Test Loss: 0.1799
# Epoch 86 Train Accuracy: 0.8939
# Epoch 86 Test Accuracy: 0.8376
# Epoch 86/500 - LR: 0.0000009766 - Train Loss: 0.0896 - Test Loss: 0.1782
# Epoch 87 Train Accuracy: 0.8952
# Epoch 87 Test Accuracy: 0.8313
# Epoch 87/500 - LR: 0.0000009766 - Train Loss: 0.0887 - Test Loss: 0.1862
# Epoch 88 Train Accuracy: 0.8962
# Epoch 88 Test Accuracy: 0.8438
# Epoch 88/500 - LR: 0.0000009766 - Train Loss: 0.0883 - Test Loss: 0.1715
# Epoch 89 Train Accuracy: 0.8955
# Epoch 89 Test Accuracy: 0.8325
# Epoch 89/500 - LR: 0.0000009766 - Train Loss: 0.0876 - Test Loss: 0.1814
# Epoch 90 Train Accuracy: 0.8967
# Epoch 90 Test Accuracy: 0.8364
# Epoch 90/500 - LR: 0.0000009766 - Train Loss: 0.0877 - Test Loss: 0.1831
# Epoch 91 Train Accuracy: 0.8991
# Epoch 91 Test Accuracy: 0.8374
# Epoch 91/500 - LR: 0.0000009766 - Train Loss: 0.0874 - Test Loss: 0.1768
# Epoch 92 Train Accuracy: 0.8938
# Epoch 92 Test Accuracy: 0.8434
# Epoch 92/500 - LR: 0.0000004883 - Train Loss: 0.0889 - Test Loss: 0.1721
# Epoch 93 Train Accuracy: 0.8945
# Epoch 93 Test Accuracy: 0.8310
# Epoch 93/500 - LR: 0.0000004883 - Train Loss: 0.0894 - Test Loss: 0.1857
# Epoch 94 Train Accuracy: 0.8965
# Epoch 94 Test Accuracy: 0.8387
# Epoch 94/500 - LR: 0.0000004883 - Train Loss: 0.0886 - Test Loss: 0.1768
# Epoch 95 Train Accuracy: 0.8975
# Epoch 95 Test Accuracy: 0.8140
# Epoch 95/500 - LR: 0.0000004883 - Train Loss: 0.0872 - Test Loss: 0.1968
# Epoch 96 Train Accuracy: 0.8946
# Epoch 96 Test Accuracy: 0.8295
# Epoch 96/500 - LR: 0.0000004883 - Train Loss: 0.0887 - Test Loss: 0.1855
# Epoch 97 Train Accuracy: 0.8947
# Epoch 97 Test Accuracy: 0.8409
# Epoch 97/500 - LR: 0.0000004883 - Train Loss: 0.0880 - Test Loss: 0.1780
# Epoch 98 Train Accuracy: 0.8947
# Epoch 98 Test Accuracy: 0.8466
# Epoch 98/500 - LR: 0.0000002441 - Train Loss: 0.0888 - Test Loss: 0.1663
# Epoch 99 Train Accuracy: 0.8958
# Epoch 99 Test Accuracy: 0.8438
# Epoch 99/500 - LR: 0.0000002441 - Train Loss: 0.0875 - Test Loss: 0.1713
# Epoch 100 Train Accuracy: 0.8932
# Epoch 100 Test Accuracy: 0.8403
# Epoch 100/500 - LR: 0.0000002441 - Train Loss: 0.0886 - Test Loss: 0.1748
# Epoch 101 Train Accuracy: 0.8940
# Epoch 101 Test Accuracy: 0.8441
# Epoch 101/500 - LR: 0.0000002441 - Train Loss: 0.0892 - Test Loss: 0.1701
# Epoch 102 Train Accuracy: 0.8937
# Epoch 102 Test Accuracy: 0.8346
# Epoch 102/500 - LR: 0.0000002441 - Train Loss: 0.0891 - Test Loss: 0.1811
# Epoch 103 Train Accuracy: 0.8932
# Epoch 103 Test Accuracy: 0.8364
# Epoch 103/500 - LR: 0.0000002441 - Train Loss: 0.0891 - Test Loss: 0.1804
# Epoch 104 Train Accuracy: 0.8942
# Epoch 104 Test Accuracy: 0.8417
# Epoch 104/500 - LR: 0.0000001221 - Train Loss: 0.0895 - Test Loss: 0.1766
# Epoch 105 Train Accuracy: 0.8980
# Epoch 105 Test Accuracy: 0.8416
# Epoch 105/500 - LR: 0.0000001221 - Train Loss: 0.0877 - Test Loss: 0.1742
# Epoch 106 Train Accuracy: 0.8975
# Epoch 106 Test Accuracy: 0.8307
# Epoch 106/500 - LR: 0.0000001221 - Train Loss: 0.0874 - Test Loss: 0.1854
# Epoch 107 Train Accuracy: 0.8970
# Epoch 107 Test Accuracy: 0.8435
# Epoch 107/500 - LR: 0.0000001221 - Train Loss: 0.0879 - Test Loss: 0.1734
# Epoch 108 Train Accuracy: 0.8945
# Epoch 108 Test Accuracy: 0.8305
# Epoch 108/500 - LR: 0.0000001221 - Train Loss: 0.0893 - Test Loss: 0.1862
# Epoch 109 Train Accuracy: 0.8975
# Epoch 109 Test Accuracy: 0.8164
# Epoch 109/500 - LR: 0.0000001221 - Train Loss: 0.0870 - Test Loss: 0.1995
# Epoch 110 Train Accuracy: 0.8972
# Epoch 110 Test Accuracy: 0.8347
# Epoch 110/500 - LR: 0.0000000610 - Train Loss: 0.0876 - Test Loss: 0.1798
# Epoch 111 Train Accuracy: 0.8956
# Epoch 111 Test Accuracy: 0.8416
# Epoch 111/500 - LR: 0.0000000610 - Train Loss: 0.0883 - Test Loss: 0.1738
# Epoch 112 Train Accuracy: 0.8960
# Epoch 112 Test Accuracy: 0.8227
# Epoch 112/500 - LR: 0.0000000610 - Train Loss: 0.0884 - Test Loss: 0.1901
# Epoch 113 Train Accuracy: 0.8929
# Epoch 113 Test Accuracy: 0.8470
# Epoch 113/500 - LR: 0.0000000610 - Train Loss: 0.0892 - Test Loss: 0.1680
# Epoch 114 Train Accuracy: 0.8954
# Epoch 114 Test Accuracy: 0.8377
# Epoch 114/500 - LR: 0.0000000610 - Train Loss: 0.0886 - Test Loss: 0.1780
# Epoch 115 Train Accuracy: 0.8956
# Epoch 115 Test Accuracy: 0.8476
# Epoch 115/500 - LR: 0.0000000610 - Train Loss: 0.0878 - Test Loss: 0.1696
# Epoch 116 Train Accuracy: 0.8964
# Epoch 116 Test Accuracy: 0.8389
# Epoch 116/500 - LR: 0.0000000305 - Train Loss: 0.0879 - Test Loss: 0.1767
# Epoch 117 Train Accuracy: 0.8922
# Epoch 117 Test Accuracy: 0.8434
# Epoch 117/500 - LR: 0.0000000305 - Train Loss: 0.0889 - Test Loss: 0.1735
# Epoch 118 Train Accuracy: 0.8976
# Epoch 118 Test Accuracy: 0.8284
# Epoch 118/500 - LR: 0.0000000305 - Train Loss: 0.0877 - Test Loss: 0.1903
# Epoch 119 Train Accuracy: 0.8946
# Epoch 119 Test Accuracy: 0.8410
# Epoch 119/500 - LR: 0.0000000305 - Train Loss: 0.0883 - Test Loss: 0.1732
# Epoch 120 Train Accuracy: 0.8967
# Epoch 120 Test Accuracy: 0.8426
# Epoch 120/500 - LR: 0.0000000305 - Train Loss: 0.0875 - Test Loss: 0.1682
# Epoch 121 Train Accuracy: 0.8949
# Epoch 121 Test Accuracy: 0.8290
# Epoch 121/500 - LR: 0.0000000305 - Train Loss: 0.0887 - Test Loss: 0.1847
# Epoch 122 Train Accuracy: 0.8953
# Epoch 122 Test Accuracy: 0.8380
# Epoch 122/500 - LR: 0.0000000153 - Train Loss: 0.0876 - Test Loss: 0.1809
# Epoch 123 Train Accuracy: 0.8947
# Epoch 123 Test Accuracy: 0.8265
# Epoch 123/500 - LR: 0.0000000153 - Train Loss: 0.0882 - Test Loss: 0.1891
# Epoch 124 Train Accuracy: 0.8944
# Epoch 124 Test Accuracy: 0.8430
# Epoch 124/500 - LR: 0.0000000153 - Train Loss: 0.0882 - Test Loss: 0.1706
# Epoch 125 Train Accuracy: 0.8968
# Epoch 125 Test Accuracy: 0.8400
# Epoch 125/500 - LR: 0.0000000153 - Train Loss: 0.0878 - Test Loss: 0.1717
# Epoch 126 Train Accuracy: 0.8954
# Epoch 126 Test Accuracy: 0.8305
# Epoch 126/500 - LR: 0.0000000153 - Train Loss: 0.0882 - Test Loss: 0.1877
#  Early stopping at epoch 126 (no improvement for 100 epochs)

# %% [markdown]
# # Visualization

# %%
# visualize_embeddings.py


# model = SiameseNet(embedding_dim=EMBEDDING_DIM).to(device)
# model.load_state_dict(torch.load("only weights_siamese_model.pt", map_location=device))
# trained_model= torch.load("runs/siamese_2025-04-30_11-08_lfs_multi_channel/full_siamese_model_best.pt", weights_only=False)
# siamese_2025-04-30_14-23_lfs_multi_channel is at 80%
# siamese_2025-04-30_22-56_lfs_multi_channel is at 86% very good generalizebility since is trained on GPi and STN but seperates other brain regions too
# siamese_2025-05-01_01-13_lfs_multi_channel very good 75% trained on 5 vim 3 gpi 3stn amd 3 voavop good generalizability
trained_model.eval()
encoder_model = trained_model.encoder
encoder_model.eval()


# laod data
dataPath = get_data_directory()
with h5py.File(dataPath + "lfs data\\microGPi1_L_6_CommonFiltered_lfs.mat", "r") as f:
    raw_gpi1 = np.array(f["data"]).squeeze()
    fs = int(np.array(f["fs"]).squeeze())
with h5py.File(dataPath + "lfs data\\microGPi2_L_4_CommonFiltered_lfs.mat", "r") as f: # \\
    raw_gpi2 = np.array(f["data"]).squeeze()
with h5py.File(dataPath + "lfs data\\microSTN_L_2_CommonFiltered_lfs.mat", "r") as f:
    raw_stn1 = np.array(f["data"]).squeeze()  # replace with your actual filename
with h5py.File(dataPath + "lfs data\\microVIM_L_6_CommonFiltered_lfs.mat", "r") as f:
    raw_stn2 = np.array(f["data"]).squeeze()  # replace with your actual filename

# resample and filter 
# resampled_gpi1 = filter_and_resample(raw_gpi1, original_fs=fs, target_fs=1000, cutoff=500)
# resampled_gpi2 = filter_and_resample(raw_gpi2, original_fs=fs, target_fs=1000, cutoff=500)
# resampled_stn1 = filter_and_resample(raw_stn1, original_fs=fs, target_fs=1000, cutoff=500)
# resampled_stn2 = filter_and_resample(raw_stn2, original_fs=fs, target_fs=1000, cutoff=500)

# normalization 
# gpi_data1 = (resampled_gpi1 - np.mean(resampled_gpi1)) / np.std(resampled_gpi1)
# gpi_data2 = (resampled_gpi2 - np.mean(resampled_gpi2)) / np.std(resampled_gpi2)
# stn_data1 = (resampled_stn1 - np.mean(resampled_stn1)) / np.std(resampled_stn1)
# stn_data2 = (resampled_stn2 - np.mean(resampled_stn2)) / np.std(resampled_stn2)

# normalization 
gpi_data1 = (raw_gpi1 - np.mean(raw_gpi1)) / np.std(raw_gpi1)
gpi_data2 = (raw_gpi2 - np.mean(raw_gpi2)) / np.std(raw_gpi2)
stn_data1 = (raw_stn1 - np.mean(raw_stn1)) / np.std(raw_stn1)
stn_data2 = (raw_stn2 - np.mean(raw_stn2)) / np.std(raw_stn2)


# data segmentation 
gpi_segments1 = segment_data(gpi_data1, SEGMENT_LENGTH, shuffle=False)[:2000]  # take first 100 segments\
gpi_segments2 = segment_data(gpi_data2, SEGMENT_LENGTH, shuffle=False)[:2000]  # take first 100 segments
stn_segments1 = segment_data(stn_data1, SEGMENT_LENGTH, shuffle=False)[:2000]
stn_segments2 = segment_data(stn_data2, SEGMENT_LENGTH, shuffle=False)[:2000]

gpi_embeddings1 = extract_embeddings(encoder_model, gpi_segments1, label='GPi1_L', device=device)
gpi_embeddings2 = extract_embeddings(encoder_model, gpi_segments2, label='GPi2_L', device=device)
stn_embeddings1 = extract_embeddings(encoder_model, stn_segments1, label='STN_L', device=device)
stn_embeddings2 = extract_embeddings(encoder_model, stn_segments2, label='VIM_L', device=device)

all_embeddings = gpi_embeddings1 + gpi_embeddings2+stn_embeddings1+stn_embeddings2
# 'correlation' , 'cosine', 'manhattan' (L1 distance good for sparse),  'euclidean' (default)
# visualize(all_embeddings, TSNE_metric='euclidean')

# %%
# visualize_distance_heatmap(all_embeddings)
embeddings = np.array([e for e, _ in all_embeddings])
labels = np.array([l for _, l in all_embeddings])
# method = ["umap", "tsne", "pca"]
# metric = [["correlation" , "cosine", "manhattan",  "euclidean" ],
#           ["correlation" , "cosine", "manhattan",  "euclidean" ],
#           ['']]
# dim = ["2d", "3d"]
method = ["pca"]
metric = [[ "cosine" ]]
dim = ["2d"]
for idim in dim:
    for i, imethod in enumerate(method):
        for imetric in metric[i]:
            visualize_embeddings(embeddings, labels, method=imethod, metric=imetric, mode=idim)

# %%
# visualize_embeddings.py


# model = SiameseNet(embedding_dim=EMBEDDING_DIM).to(device)
# model.load_state_dict(torch.load("only weights_siamese_model.pt", map_location=device))
# trained_model= torch.load("runs/siamese_2025-04-23_01-03multi_channel/full_siamese_model_best.pt", weights_only=False)
trained_model.eval()
encoder_model = trained_model.encoder
encoder_model.eval()

dataPath = get_data_directory()
with h5py.File(dataPath+ "microGPi1_L_4_CommonFiltered.mat", "r") as f:
    raw_gpi1 = np.array(f["data"]).squeeze()
    fs = int(np.array(f["fs"]).squeeze())
with h5py.File(dataPath+ "microGPi1_L_6_CommonFiltered.mat", "r") as f:
    raw_gpi2 = np.array(f["data"]).squeeze()
with h5py.File(dataPath + "microSTN_L_3_CommonFiltered.mat", "r") as f:
    raw_stn1 = np.array(f["data"]).squeeze()  # replace with your actual filename
with h5py.File(dataPath + "microSTN_L_1_CommonFiltered.mat", "r") as f:
    raw_stn2 = np.array(f["data"]).squeeze()  # replace with your actual filename

# normalization 
gpi_data1 = (raw_gpi1 - np.mean(raw_gpi1)) / np.std(raw_gpi1)
gpi_data2 = (raw_gpi2 - np.mean(raw_gpi2)) / np.std(raw_gpi2)

stn_data1 = (raw_stn1 - np.mean(raw_stn1)) / np.std(raw_stn1)
stn_data2 = (raw_stn2 - np.mean(raw_stn2)) / np.std(raw_stn2)


gpi_segments1 = segment_data(gpi_data1, SEGMENT_LENGTH, shuffle=False)[:500]  # take first 100 segments\
gpi_segments2 = segment_data(gpi_data2, SEGMENT_LENGTH, shuffle=False)[:500]  # take first 100 segments
stn_segments1 = segment_data(stn_data1, SEGMENT_LENGTH, shuffle=False)[:500]
stn_segments2 = segment_data(stn_data2, SEGMENT_LENGTH, shuffle=False)[:500]

gpi_embeddings1 = extract_embeddings(encoder_model, gpi_segments1, label=0, device=device)
gpi_embeddings2 = extract_embeddings(encoder_model, gpi_segments2, label=1, device=device)
stn_embeddings1 = extract_embeddings(encoder_model, stn_segments1, label=3, device=device)
stn_embeddings2 = extract_embeddings(encoder_model, stn_segments2, label=4, device=device)

all_embeddings = gpi_embeddings1 + gpi_embeddings2+stn_embeddings1+stn_embeddings2
visualize(all_embeddings)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[141], line 13
#      11 dataPath = get_data_directory()
#      12 with h5py.File(dataPath+ "microGPi1_L_4_CommonFiltered.mat", "r") as f:
# ---> 13     raw_gpi1 = np.array(f["data"]).squeeze()
#      14     fs = int(np.array(f["fs"]).squeeze())
#      15 with h5py.File(dataPath+ "microGPi1_L_6_CommonFiltered.mat", "r") as f:
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File f:\Python Projects\NIPS2025\venv311\Lib\site-packages\h5py\_hl\dataset.py:1112, in Dataset.__array__(self, dtype, copy)
#    1109 if self.size == 0:
#    1110     return arr
# -> 1112 self.read_direct(arr)
#    1113 return arr
#
# File f:\Python Projects\NIPS2025\venv311\Lib\site-packages\h5py\_hl\dataset.py:1068, in Dataset.read_direct(self, dest, source_sel, dest_sel)
#    1065     dest_sel = sel.select(dest.shape, dest_sel)
#    1067 for mspace in dest_sel.broadcast(source_sel.array_shape):
# -> 1068     self.id.read(mspace, fspace, dest, dxpl=self._dxpl)
#
# KeyboardInterrupt:

# %% [markdown]
# # To do:
#
# To be done:
# - Clean the codes a bit, make embedding dimensions and dropout and other hyper parameters, parameters so you can save them during saving optimizer and scheduler and loss function can be saved some other way
# - Somehow save validation results for each model that you save
# - visualize the entire brain a good fuction where left and right side brain have different markers and each region have a color that slightly changes brithness for different electrodes or another strategy for different electrodes, you can also try only one lead per
# - try 4 different contrastive learning loss functions
# - try removing sections without enough variance through the use of ax pool or discardings segments. or giving out a probability.
# - Compare a bunch of candiate models and hyper parameters
# - Add clustering accuracy for other regions and distance metrics to check generalizability
# - Start transformer code starting with predicting future or EMG
# - Start integrating over multiple sessions and multiple days and multiple subjects
# - Look at explainable ai and its technic to see what features it learns to segregate regions, maybe add a generative part to see what it generates, or give it different characteristic inputs to see which one it is sesetive to (different frq bands)
# - Start to see how these locations can be used for the paper (comparison of multi day embeddings or multi subject, or left or right)
# - Add testing as well
# - Should I add more time in the window and replace average with max pool with the aim to just consider time windows who actually show some variation bc all the regions do have times in which they have near 0 energy
# - Adaptive pool can Also give certain number of outputs so can use 5 instead of 1 can use max pool too
# - A better visualization that can recieve embeddings and their labels and use it in the legend
# - try very low dimension embedded space
# - add new visualizations and analysis to give you an idea if the learning was successful (get inspirartion from other papers)
# - how do these embedding change during behavior, is there a multimodal behavior to some regions so if we take histogram distributions along PCA dimention how do they look like
# - how are they different between left and right brain and within and between brain regions.
# - how do these change along the days and between tasks
# - if the task was the same this would have captured GPi functionality and timing charachetritics comparing to STN and other regions so can be very useful for same task datasets
# - studies including seeing what parameters is each region recognized by
# - seeing where regions change in 1 lead
#
#
#
# Done:
# - When getting segments add an option for shuffeling so theat when testing you dont wnat to shuffle so ypu have an idea of its time
# - Add new visualization since tnse is wierd or add other tnse metrics: already did so test it and also change it such that any label could be coorectly legended(perhaps just give the label name with it)
# - Add matlab for filtering since its so slow here in python
# - Add sampling for a genral input from many classes (input as a dictionary)
# - Write the code to visualize in all embeddings (done)
